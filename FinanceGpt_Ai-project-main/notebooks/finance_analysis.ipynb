# %% [markdown]
# # Finance GPT AI - Exploratory Data Analysis
# Welcome to the notebook! As your trainer, I recommend using this space to experiment with the generated datasets before adding them to Streamlit.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the stock data
df = pd.read_csv('../datasets/stock_prices.csv')
df.head()
